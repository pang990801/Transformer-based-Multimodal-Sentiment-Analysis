# %%
import os

import numpy as np
from mmsdk import mmdatasdk as md
import h5py

MOSI_PATH = "F:\MOSEI\model\data\MOSI\cmumosi"
MOSI_DATASET = md.cmu_mosi

# cmumosi_highlevel=md.mmdataset(MOSI_DATASET.highlevel, MOSI_PATH)
# cmumosi_raw=md.mmdataset(MOSI_DATASET.raw, MOSI_PATH)
# cmumosi_labels=md.mmdataset(MOSI_DATASET.labels, MOSI_PATH)

visual_field = 'CMU_MOSI_Visual_Facet_42'
acoustic_field = 'CMU_MOSI_COVAREP'
text_field = 'CMU_MOSI_TimestampedWords'

features = [
    text_field,
    visual_field,
    acoustic_field
]

recipe = {feat: os.path.join(MOSI_PATH, feat) + '.csd' for feat in features}
dataset = md.mmdataset(recipe)


# we define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features


# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field, collapse_functions=[avg])

label_field = 'CMU_MOSI_Opinion_Labels'

# we add and align to lables to obtain labeled segments
# this time we don't apply collapse functions so that the temporal sequences are preserved
label_recipe = {label_field: os.path.join(MOSI_PATH, label_field + '.csd')}
dataset.add_computational_sequences(label_recipe, destination=None)
dataset.align(label_field)
# Out:
# [2024-12-26 19:14:25.188] | Success | Computational sequence read from file F:\MOSEI\model\data\MOSI\cmumosi\CMU_MOSI_TimestampedWords.csd ...
# [2024-12-26 19:14:25.197] | Status  | Checking the integrity of the <words> computational sequence ...
# [2024-12-26 19:14:25.197] | Status  | Checking the format of the data in <words> computational sequence ...
# [2024-12-26 19:14:25.221] | Success | <words> computational sequence data in correct format.
# [2024-12-26 19:14:25.221] | Status  | Checking the format of the metadata in <words> computational sequence ...
# [2024-12-26 19:14:25.221] | Warning | <words> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:14:25.228] | Success | Computational sequence read from file F:\MOSEI\model\data\MOSI\cmumosi\CMU_MOSI_Visual_Facet_42.csd ...
# [2024-12-26 19:14:25.239] | Status  | Checking the integrity of the <FACET_4.2> computational sequence ...
# [2024-12-26 19:14:25.239] | Status  | Checking the format of the data in <FACET_4.2> computational sequence ...
# [2024-12-26 19:14:25.280] | Success | <FACET_4.2> computational sequence data in correct format.
# [2024-12-26 19:14:25.280] | Status  | Checking the format of the metadata in <FACET_4.2> computational sequence ...
# [2024-12-26 19:14:25.280] | Warning | <FACET_4.2> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:14:25.287] | Success | Computational sequence read from file F:\MOSEI\model\data\MOSI\cmumosi\CMU_MOSI_COVAREP.csd ...
# [2024-12-26 19:14:25.296] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-12-26 19:14:25.296] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-12-26 19:14:25.328] | Success | <COVAREP> computational sequence data in correct format.
# [2024-12-26 19:14:25.329] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-12-26 19:14:25.329] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:14:25.329] | Success | Dataset initialized successfully ...
# [2024-12-26 19:14:25.329] | Status  | Unify was called ...
# [2024-12-26 19:14:25.329] | Warning | c5xsKMxpXnc entry is not shared among all sequences, removing it ...
# [2024-12-26 19:14:25.329] | Success | Unify completed ...
# [2024-12-26 19:14:25.329] | Status  | Pre-alignment based on <CMU_MOSI_TimestampedWords> computational sequence started ...
# [2024-12-26 19:14:28.071] | Status  | Pre-alignment done for <CMU_MOSI_COVAREP> ...
# [2024-12-26 19:14:28.666] | Status  | Pre-alignment done for <CMU_MOSI_Visual_Facet_42> ...
# [2024-12-26 19:14:28.719] | Status  | Alignment starting ...
# Overall Progress:   0%|          | 0/92 [00:00<?, ? Computational Sequence Entries/s]
#   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:   0%|          | 0/464 [00:00<?, ? Segments/s]
# Aligning 03bSnISJMiM:  19%|█▉        | 90/464 [00:00<00:00, 894.06 Segments/s]
# Aligning 03bSnISJMiM:  42%|████▏     | 193/464 [00:00<00:00, 969.13 Segments/s]
# Aligning 03bSnISJMiM:  62%|██████▎   | 290/464 [00:00<00:00, 951.41 Segments/s]
# Aligning 03bSnISJMiM:  83%|████████▎ | 386/464 [00:00<00:00, 945.20 Segments/s]
# Overall Progress:   1%|          | 1/92 [00:00<00:44,  2.03 Computational Sequence Entries/s]
#   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:   0%|          | 0/485 [00:00<?, ? Segments/s]
# Aligning 0h-zjBukYpk:  20%|█▉        | 95/485 [00:00<00:00, 949.35 Segments/s]
# Aligning 0h-zjBukYpk:  40%|████      | 195/485 [00:00<00:00, 978.66 Segments/s]
# Aligning 0h-zjBukYpk:  61%|██████    | 296/485 [00:00<00:00, 987.22 Segments/s]
# Aligning 0h-zjBukYpk:  81%|████████▏ | 395/485 [00:00<00:00, 930.25 Segments/s]
# Overall Progress:   2%|▏         | 2/92 [00:01<00:46,  1.95 Computational Sequence Entries/s]
#   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:   0%|          | 0/237 [00:00<?, ? Segments/s]
# Aligning 1DmNV9C1hbY:  54%|█████▍    | 128/237 [00:00<00:00, 1268.66 Segments/s]
# Overall Progress:   3%|▎         | 3/92 [00:01<00:32,  2.71 Computational Sequence Entries/s]
#   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:   0%|          | 0/562 [00:00<?, ? Segments/s]
# Aligning 1iG0909rllw:  18%|█▊        | 99/562 [00:00<00:00, 983.41 Segments/s]
# Aligning 1iG0909rllw:  36%|███▌      | 202/562 [00:00<00:00, 1009.56 Segments/s]
# Aligning 1iG0909rllw:  54%|█████▍    | 303/562 [00:00<00:00, 1001.16 Segments/s]
# Aligning 1iG0909rllw:  72%|███████▏  | 404/562 [00:00<00:00, 993.13 Segments/s]
# Aligning 1iG0909rllw:  91%|█████████ | 509/562 [00:00<00:00, 1009.83 Segments/s]
# Overall Progress:   4%|▍         | 4/92 [00:01<00:39,  2.24 Computational Sequence Entries/s]
#   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:   0%|          | 0/651 [00:00<?, ? Segments/s]
# Aligning 2WGyTLYerpo:  13%|█▎        | 87/651 [00:00<00:00, 866.51 Segments/s]
# Aligning 2WGyTLYerpo:  29%|██▉       | 190/651 [00:00<00:00, 957.43 Segments/s]
# Aligning 2WGyTLYerpo:  44%|████▍     | 286/651 [00:00<00:00, 955.47 Segments/s]
# Aligning 2WGyTLYerpo:  59%|█████▊    | 382/651 [00:00<00:00, 949.87 Segments/s]
# Aligning 2WGyTLYerpo:  74%|███████▍  | 483/651 [00:00<00:00, 968.18 Segments/s]
# Aligning 2WGyTLYerpo:  89%|████████▉ | 580/651 [00:00<00:00, 954.51 Segments/s]
# Overall Progress:   5%|▌         | 5/92 [00:02<00:46,  1.86 Computational Sequence Entries/s]
#   0%|          | 0/700 [00:00<?, ? Segments/s]
# Aligning 2iD-tVS8NPw
 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:   0%|          | 0/554 [00:00<?, ? Segments/s]
# Aligning 9J25DZhivz8:  15%|█▌        | 84/554 [00:00<00:00, 837.86 Segments/s]
# Aligning 9J25DZhivz8:  30%|███       | 168/554 [00:00<00:00, 821.67 Segments/s]
# Aligning 9J25DZhivz8:  48%|████▊     | 265/554 [00:00<00:00, 881.41 Segments/s]
# Aligning 9J25DZhivz8:  65%|██████▍   | 360/554 [00:00<00:00, 906.57 Segments/s]
# Aligning 9J25DZhivz8:  81%|████████▏ | 451/554 [00:00<00:00, 903.31 Segments/s]
# Aligning 9J25DZhivz8: 100%|█████████▉| 553/554 [00:00<00:00, 940.12 Segments/s]
# Overall Progress:  16%|█▋        | 15/92 [00:07<00:45,  1.70 Computational Sequence Entries/s]
#   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:   0%|          | 0/645 [00:00<?, ? Segments/s]
# Aligning 9T9Hf74oK10:  17%|█▋        | 109/645 [00:00<00:00, 1087.99 Segments/s]
# Aligning 9T9Hf74oK10:  34%|███▍      | 218/645 [00:00<00:00, 960.02 Segments/s]
# Aligning 9T9Hf74oK10:  49%|████▉     | 318/645 [00:00<00:00, 975.33 Segments/s]
# Aligning 9T9Hf74oK10:  65%|██████▍   | 417/645 [00:00<00:00, 916.97 Segments/s]
# Aligning 9T9Hf74oK10:  79%|███████▉  | 510/645 [00:00<00:00, 920.64 Segments/s]
# Aligning 9T9Hf74oK10:  93%|█████████▎| 603/645 [00:00<00:00, 905.13 Segments/s]
# Overall Progress:  17%|█▋        | 16/92 [00:08<00:47,  1.61 Computational Sequence Entries/s]
#   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:   0%|          | 0/300 [00:00<?, ? Segments/s]
# Aligning 9c67fiY0wGQ:  43%|████▎     | 129/300 [00:00<00:00, 1286.37 Segments/s]
# Aligning 9c67fiY0wGQ:  86%|████████▌ | 258/300 [00:00<00:00, 1202.62 Segments/s]
# Overall Progress:  18%|█▊        | 17/92 [00:08<00:38,  1.95 Computational Sequence Entries/s]
#   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:   0%|          | 0/735 [00:00<?, ? Segments/s]
# Aligning 9qR7uwkblbs:  13%|█▎        | 97/735 [00:00<00:00, 962.29 Segments/s]
# Aligning 9qR7uwkblbs:  27%|██▋       | 195/735 [00:00<00:00, 967.26 Segments/s]
# Aligning 9qR7uwkblbs:  40%|████      | 297/735 [00:00<00:00, 986.18 Segments/s]
# Aligning 9qR7uwkblbs:  54%|█████▍    | 396/735 [00:00<00:00, 976.19 Segments/s]
# Aligning 9qR7uwkblbs:  67%|██████▋   | 494/735 [00:00<00:00, 911.44 Segments/s]
# Aligning 9qR7uwkblbs:  80%|███████▉  | 586/735 [00:00<00:00, 901.82 Segments/s]
# Aligning 9qR7uwkblbs:  93%|█████████▎| 681/735 [00:00<00:00, 912.84 Segments/s]
# Overall Progress:  20%|█▉        | 18/92 [00:09<00:44,  1.67 Computational Sequence Entries/s]
#   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:   0%|          | 0/659 [00:00<?, ? Segments/s]
# Aligning Af8D0E4ZXaw:  15%|█▍        | 96/659 [00:00<00:00, 958.00 Segments/s]
# Aligning Af8D0E4ZXaw:  30%|██▉       | 197/659 [00:00<00:00, 983.21 Segments/s]
# Aligning Af8D0E4ZXaw:  45%|████▍     | 296/659 [00:00<00:00, 955.64 Segments/s]
# Aligning Af8D0E4ZXaw:  59%|█████▉    | 392/659 [00:00<00:00, 943.86 Segments/s]
# Aligning Af8D0E4ZXaw:  74%|███████▍  | 487/659 [00:00<00:00, 919.21 Segments/s]
# Aligning Af8D0E4ZXaw:  88%|████████▊ | 580/659 [00:00<00:00, 919.07 Segments/s]
# Overall Progress:  21%|██        | 19/92 [00:10<00:46,  1.57 Computational Sequence Entries/s]
#   0%|          | 0/406 [00:00<?, ? Segments/s]
# Aligning BI97DNYfe5I
[00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:  12%|█▏        | 95/763 [00:00<00:00, 945.61 Segments/s]
# Aligning G6GlGvlkxAQ:  25%|██▍       | 190/763 [00:00<00:00, 929.54 Segments/s]
# Aligning G6GlGvlkxAQ:  38%|███▊      | 288/763 [00:00<00:00, 951.85 Segments/s]
# Aligning G6GlGvlkxAQ:  51%|█████     | 386/763 [00:00<00:00, 962.79 Segments/s]
# Aligning G6GlGvlkxAQ:  63%|██████▎   | 484/763 [00:00<00:00, 968.25 Segments/s]
# Aligning G6GlGvlkxAQ:  77%|███████▋  | 584/763 [00:00<00:00, 975.68 Segments/s]
# Aligning G6GlGvlkxAQ:  90%|████████▉ | 686/763 [00:00<00:00, 988.89 Segments/s]
# Overall Progress:  32%|███▏      | 29/92 [00:16<00:38,  1.62 Computational Sequence Entries/s]
#   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/417 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:  26%|██▌       | 109/417 [00:00<00:00, 1088.91 Segments/s]
# Aligning GWuJjcEuzt8:  53%|█████▎    | 222/417 [00:00<00:00, 1111.25 Segments/s]
# Aligning GWuJjcEuzt8:  81%|████████  | 337/417 [00:00<00:00, 1125.14 Segments/s]
# Overall Progress:  33%|███▎      | 30/92 [00:16<00:33,  1.84 Computational Sequence Entries/s]
#   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/622 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:  17%|█▋        | 108/622 [00:00<00:00, 1077.64 Segments/s]
# Aligning HEsqda8_d0Q:  36%|███▌      | 223/622 [00:00<00:00, 1119.90 Segments/s]
# Aligning HEsqda8_d0Q:  54%|█████▍    | 337/622 [00:00<00:00, 1124.18 Segments/s]
# Aligning HEsqda8_d0Q:  72%|███████▏  | 450/622 [00:00<00:00, 1071.28 Segments/s]
# Aligning HEsqda8_d0Q:  90%|████████▉ | 558/622 [00:00<00:00, 1056.68 Segments/s]
# Overall Progress:  34%|███▎      | 31/92 [00:17<00:34,  1.79 Computational Sequence Entries/s]
#   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/640 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:  17%|█▋        | 106/640 [00:00<00:00, 1052.56 Segments/s]
# Aligning I5y0__X72p0:  33%|███▎      | 212/640 [00:00<00:00, 1040.40 Segments/s]
# Aligning I5y0__X72p0:  50%|████▉     | 317/640 [00:00<00:00, 1043.13 Segments/s]
# Aligning I5y0__X72p0:  66%|██████▌   | 422/640 [00:00<00:00, 1026.33 Segments/s]
# Aligning I5y0__X72p0:  82%|████████▏ | 525/640 [00:00<00:00, 1011.35 Segments/s]
# Aligning I5y0__X72p0:  98%|█████████▊| 627/640 [00:00<00:00, 1002.40 Segments/s]
# Overall Progress:  35%|███▍      | 32/92 [00:17<00:34,  1.72 Computational Sequence Entries/s]
#   0%|          | 0/316 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|          | 0/316 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:  40%|████      | 127/316 [00:00<00:00, 1258.37 Segments/s]
# Aligning Iu2PFX3z_1s:  80%|████████  | 253/316 [00:00<00:00, 1221.38 Segments/s]
# Overall Progress:  36%|███▌      | 33/92 [00:17<00:28,  2.06 Computational Sequence Entries/s]
#   0%|          | 0/450 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|          | 0/450 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:  27%|██▋       | 120/450 [00:00<00:00, 1195.76 Segments/s]
# Aligning IumbAb8q2dM:  54%|█████▍    | 244/450 [00:00<00:00, 1221.55 Segments/s]
# Aligning IumbAb8q2dM:  82%|████████▏ | 367/450 [00:00<00:00, 1168.66 Segments/s]
# Overall Progress:  37%|███▋      | 34/92 [00:18<00:26,  2.18 Computational Sequence Entries/s]
#   0%|          | 0/219 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|          | 0/219 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk
[00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:  16%|█▌        | 99/622 [00:00<00:00, 981.15 Segments/s]
# Aligning Vj1wYRQjB-o:  33%|███▎      | 204/622 [00:00<00:00, 1016.09 Segments/s]
# Aligning Vj1wYRQjB-o:  50%|█████     | 313/622 [00:00<00:00, 1049.23 Segments/s]
# Aligning Vj1wYRQjB-o:  67%|██████▋   | 418/622 [00:00<00:00, 1033.24 Segments/s]
# Aligning Vj1wYRQjB-o:  84%|████████▍ | 522/622 [00:00<00:00, 967.02 Segments/s]
# Aligning Vj1wYRQjB-o: 100%|█████████▉| 620/622 [00:00<00:00, 964.09 Segments/s]
# Overall Progress:  55%|█████▌    | 51/92 [00:27<00:25,  1.61 Computational Sequence Entries/s]
#   0%|          | 0/612 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|          | 0/612 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:  16%|█▌        | 98/612 [00:00<00:00, 978.42 Segments/s]
# Aligning W8NXH0Djyww:  33%|███▎      | 205/612 [00:00<00:00, 1030.95 Segments/s]
# Aligning W8NXH0Djyww:  50%|█████     | 309/612 [00:00<00:00, 998.82 Segments/s]
# Aligning W8NXH0Djyww:  67%|██████▋   | 410/612 [00:00<00:00, 974.18 Segments/s]
# Aligning W8NXH0Djyww:  83%|████████▎ | 508/612 [00:00<00:00, 959.26 Segments/s]
# Overall Progress:  57%|█████▋    | 52/92 [00:27<00:24,  1.61 Computational Sequence Entries/s]
#   0%|          | 0/621 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:   0%|          | 0/621 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:  15%|█▍        | 93/621 [00:00<00:00, 927.39 Segments/s]
# Aligning WKA5OygbEKI:  31%|███       | 194/621 [00:00<00:00, 971.95 Segments/s]
# Aligning WKA5OygbEKI:  48%|████▊     | 299/621 [00:00<00:00, 1003.99 Segments/s]
# Aligning WKA5OygbEKI:  64%|██████▍   | 400/621 [00:00<00:00, 976.47 Segments/s]
# Aligning WKA5OygbEKI:  80%|████████  | 498/621 [00:00<00:00, 936.20 Segments/s]
# Aligning WKA5OygbEKI:  96%|█████████▌| 596/621 [00:00<00:00, 947.94 Segments/s]
# Overall Progress:  58%|█████▊    | 53/92 [00:28<00:24,  1.58 Computational Sequence Entries/s]
#   0%|          | 0/249 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:   0%|          | 0/249 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:  52%|█████▏    | 129/249 [00:00<00:00, 1288.82 Segments/s]
# Overall Progress:  59%|█████▊    | 54/92 [00:28<00:19,  2.00 Computational Sequence Entries/s]
#   0%|          | 0/220 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:   0%|          | 0/220 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:  70%|██████▉   | 153/220 [00:00<00:00, 1518.53 Segments/s]
# Overall Progress:  60%|█████▉    | 55/92 [00:28<00:14,  2.52 Computational Sequence Entries/s]
#   0%|          | 0/537 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:   0%|          | 0/537 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:  19%|█▉        | 101/537 [00:00<00:00, 998.88 Segments/s]
# Aligning ZUXBRvtny7o:  38%|███▊      | 206/537 [00:00<00:00, 1023.51 Segments/s]
# Aligning ZUXBRvtny7o:  59%|█████▉    | 316/537 [00:00<00:00, 1055.78 Segments/s]
# Aligning ZUXBRvtny7o:  79%|███████▊  | 422/537 [00:00<00:00, 1004.85 Segments/s]
# Aligning ZUXBRvtny7o:  97%|█████████▋| 523/537 [00:00<00:00, 968.14 Segments/s]
# Overall Progress:  61%|██████    | 56/92 [00:29<00:15,  2.26 Computational Sequence Entries/s]
#   0%|          | 0/675 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:   0%|          | 0/675 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:  15%|█▍        | 99/675 [00:00<00:00, 988.66 Segments/s]
# Aligning _dI--eQ6qVU:  30%|███       | 203/675 [00:00<00:00, 1014.95 Segments/s]
# Aligning _dI--eQ6qVU:  45%|████▌     | 305/675 [00:00<00:00, 996.38 Segments/s]
# Aligning _dI--eQ6qVU:  60%|██████    | 405/675 [00:00<00:00, 938.99 Segments/s]
# Aligning _dI--eQ6qVU:  74%|███████▍  | 502/675 [00:00<00:00, 949.34 Segments/s]
# Aligning _dI--eQ6qVU:  89%|████████▉ | 604/675 [00:00<00:00, 970.09 Segments/s]
# Overall Progress:  62%|██████▏   | 57/92 [00:29<00:18,  1.93 Computational Sequence Entries/s]
#   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:   0%|          | 0/591 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:  17%|█▋        | 98/591 [00:00<00:00, 974.58 Segments/s]
# Aligning aiEXnCPZubE:  34%|███▍      | 202/591 [00:00<00:00, 1011.87 Segments/s]
# Aligning aiEXnCPZubE:  51%|█████▏    | 304/591 [00:00<00:00, 983.01 Segments/s]
# Aligning aiEXnCPZubE:  68%|██████▊   | 403/591 [00:00<00:00, 964.31 Segments/s]
# Aligning aiEXnCPZubE:  85%|████████▍ | 500/591 [00:00<00:00, 946.63 Segments/s]
# Overall Progress:  63%|██████▎   | 58/92 [00:30<00:18,  1.82 Computational Sequence Entries/s]
#   0%|          | 0/557 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:   0%|          | 0/557 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:  19%|█▉        | 107/557 [00:00<00:00, 1063.88 Segments/s]
# Aligning atnd_PF-Lbs:  38%|███▊      | 214/557 [00:00<00:00, 1036.89 Segments/s]
# Aligning atnd_PF-Lbs:  57%|█████▋    | 318/557 [00:00<00:00, 1017.61 Segments/s]
# Aligning atnd_PF-Lbs:  75%|███████▌  | 420/557 [00:00<00:00, 1016.59 Segments/s]
# Aligning atnd_PF-Lbs:  94%|█████████▎| 522/557 [00:00<00:00, 1001.14 Segments/s]
# Overall Progress:  64%|██████▍   | 59/92 [00:31<00:18,  1.81 Computational Sequence Entries/s]
#   0%|          | 0/443 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:   0%|          | 0/443 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:  26%|██▌       | 115/443 [00:00<00:00, 1147.90 Segments/s]
# Aligning bOL9jKpeJRs:  52%|█████▏    | 230/443 [00:00<00:00, 1085.53 Segments/s]
# Aligning bOL9jKpeJRs:  77%|███████▋  | 339/443 [00:00<00:00, 1063.53 Segments/s]
# Overall Progress:  65%|██████▌   | 60/92 [00:31<00:16,  1.96 Computational Sequence Entries/s]
#   0%|          | 0/595 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:   0%|          | 0/595 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:  16%|█▌        | 95/595 [00:00<00:00, 941.83 Segments/s]
# Aligning bvLlb-M3UXU:  32%|███▏      | 190/595 [00:00<00:00, 943.21 Segments/s]
# Aligning bvLlb-M3UXU:  48%|████▊     | 285/595 [00:00<00:00, 919.10 Segments/s]
# Aligning bvLlb-M3UXU:  64%|██████▍   | 382/595 [00:00<00:00, 935.41 Segments/s]
# Aligning bvLlb-M3UXU:  80%|████████  | 478/595 [00:00<00:00, 943.80 Segments/s]
# Aligning bvLlb-M3UXU:  97%|█████████▋| 579/595 [00:00<00:00, 965.97 Segments/s]
# Overall Progress:  66%|██████▋   | 61/92 [00:32<00:16,  1.83 Computational Sequence Entries/s]
#   0%|          | 0/448 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:   0%|          | 0/448 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:  24%|██▍       | 108/448 [00:00<00:00, 1073.01 Segments/s]
# Aligning c7UH_rxdZv4:  48%|████▊     | 216/448 [00:00<00:00, 1057.57 Segments/s]
# Aligning c7UH_rxdZv4:  72%|███████▏  | 322/448 [00:00<00:00, 1052.22 Segments/s]
# Aligning c7UH_rxdZv4:  96%|█████████▌| 428/448 [00:00<00:00, 1012.96 Segments/s]
# Overall Progress:  67%|██████▋   | 62/92 [00:32<00:15,  1.94 Computational Sequence Entries/s]
#   0%|          | 0/548 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:   0%|          | 0/548 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:  19%|█▊        | 102/548 [00:00<00:00, 1005.13 Segments/s]
# Aligning cM3Yna7AavY:  38%|███▊      | 209/548 [00:00<00:00, 1040.23 Segments/s]
# Aligning cM3Yna7AavY:  57%|█████▋    | 314/548 [00:00<00:00, 995.92 Segments/s]
# Aligning cM3Yna7AavY:  76%|███████▌  | 414/548 [00:00<00:00, 982.79 Segments/s]
# Aligning cM3Yna7AavY:  94%|█████████▎| 513/548 [00:00<00:00, 955.34 Segments/s]
# Overall Progress:  68%|██████▊   | 63/92 [00:33<00:15,  1.89 Computational Sequence Entries/s]
#   0%|          | 0/497 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:   0%|          | 0/497 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:  18%|█▊        | 89/497 [00:00<00:00, 883.38 Segments/s]
# Aligning cW1FSBF59ik:  38%|███▊      | 191/497 [00:00<00:00, 959.23 Segments/s]
# Aligning cW1FSBF59ik:  60%|█████▉    | 296/497 [00:00<00:00, 999.85 Segments/s]
# Aligning cW1FSBF59ik:  80%|████████  | 398/497 [00:00<00:00, 1007.78 Segments/s]
# Overall Progress:  70%|██████▉   | 64/92 [00:33<00:14,  1.92 Computational Sequence Entries/s]
#   0%|          | 0/717 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:   0%|          | 0/717 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:  14%|█▍        | 103/717 [00:00<00:00, 1021.96 Segments/s]
# Aligning cXypl4FnoZo:  29%|██▊       | 206/717 [00:00<00:00, 1010.43 Segments/s]
# Aligning cXypl4FnoZo:  43%|████▎     | 308/717 [00:00<00:00, 984.82 Segments/s]
# Aligning cXypl4FnoZo:  57%|█████▋    | 409/717 [00:00<00:00, 992.13 Segments/s]
# Aligning cXypl4FnoZo:  71%|███████   | 509/717 [00:00<00:00, 985.85 Segments/s]
# Aligning cXypl4FnoZo:  85%|████████▌ | 612/717 [00:00<00:00, 999.69 Segments/s]
# Aligning cXypl4FnoZo:  99%|█████████▉| 713/717 [00:00<00:00, 999.50 Segments/s]
# Overall Progress:  71%|███████   | 65/92 [00:34<00:15,  1.72 Computational Sequence Entries/s]
#   0%|          | 0/572 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:   0%|          | 0/572 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:  19%|█▊        | 106/572 [00:00<00:00, 1057.49 Segments/s]
# Aligning d3_k5Xpfmik:  37%|███▋      | 212/572 [00:00<00:00, 1054.44 Segments/s]
# Aligning d3_k5Xpfmik:  56%|█████▌    | 318/572 [00:00<00:00, 1021.48 Segments/s]
# Aligning d3_k5Xpfmik:  74%|███████▎  | 421/572 [00:00<00:00, 985.54 Segments/s]
# Aligning d3_k5Xpfmik:  91%|█████████ | 520/572 [00:00<00:00, 930.68 Segments/s]
# Overall Progress:  72%|███████▏  | 66/92 [00:34<00:15,  1.71 Computational Sequence Entries/s]
#   0%|          | 0/481 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:   0%|          | 0/481 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:  21%|██        | 102/481 [00:00<00:00, 1011.96 Segments/s]
# Aligning d6hH302o4v8:  45%|████▍     | 216/481 [00:00<00:00, 1063.24 Segments/s]
# Aligning d6hH302o4v8:  68%|██████▊   | 325/481 [00:00<00:00, 1074.87 Segments/s]
# Aligning d6hH302o4v8:  91%|█████████ | 437/481 [00:00<00:00, 1090.91 Segments/s]
# Overall Progress:  73%|███████▎  | 67/92 [00:35<00:13,  1.84 Computational Sequence Entries/s]
#   0%|          | 0/287 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:   0%|          | 0/287 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:  43%|████▎     | 124/287 [00:00<00:00, 1238.52 Segments/s]
# Aligning dq3Nf_lMPnE:  89%|████████▉ | 256/287 [00:00<00:00, 1281.43 Segments/s]
# Overall Progress:  74%|███████▍  | 68/92 [00:35<00:10,  2.22 Computational Sequence Entries/s]
#   0%|          | 0/687 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:   0%|          | 0/687 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:  14%|█▍        | 97/687 [00:00<00:00, 961.19 Segments/s]
# Aligning etzxEpPuc6I:  30%|██▉       | 203/687 [00:00<00:00, 1014.41 Segments/s]
# Aligning etzxEpPuc6I:  44%|████▍     | 305/687 [00:00<00:00, 1016.88 Segments/s]
# Aligning etzxEpPuc6I:  59%|█████▉    | 407/687 [00:00<00:00, 988.98 Segments/s]
# Aligning etzxEpPuc6I:  74%|███████▍  | 507/687 [00:00<00:00, 967.85 Segments/s]
# Aligning etzxEpPuc6I:  88%|████████▊ | 604/687 [00:00<00:00, 963.78 Segments/s]
# Overall Progress:  75%|███████▌  | 69/92 [00:36<00:12,  1.90 Computational Sequence Entries/s]
#   0%|          | 0/500 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:   0%|          | 0/500 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:  20%|██        | 102/500 [00:00<00:00, 1008.03 Segments/s]
# Aligning f9O3YtZ2VfI:  41%|████      | 206/500 [00:00<00:00, 1021.03 Segments/s]
# Aligning f9O3YtZ2VfI:  62%|██████▏   | 309/500 [00:00<00:00, 1015.26 Segments/s]
# Aligning f9O3YtZ2VfI:  82%|████████▏ | 411/500 [00:00<00:00, 1015.50 Segments/s]
# Overall Progress:  76%|███████▌  | 70/92 [00:36<00:11,  1.93 Computational Sequence Entries/s]
#   0%|          | 0/456 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:   0%|          | 0/456 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:  22%|██▏       | 102/456 [00:00<00:00, 1012.77 Segments/s]
# Aligning f_pcplsH_V0:  45%|████▍     | 204/456 [00:00<00:00, 986.01 Segments/s]
# Aligning f_pcplsH_V0:  67%|██████▋   | 306/456 [00:00<00:00, 999.63 Segments/s]
# Aligning f_pcplsH_V0:  90%|████████▉ | 410/456 [00:00<00:00, 1011.82 Segments/s]
# Overall Progress:  77%|███████▋  | 71/92 [00:37<00:10,  2.00 Computational Sequence Entries/s]
#   0%|          | 0/642 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:   0%|          | 0/642 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:  14%|█▍        | 91/642 [00:00<00:00, 904.04 Segments/s]
# Aligning fvVhgmXxadc:  29%|██▉       | 187/642 [00:00<00:00, 934.66 Segments/s]
# Aligning fvVhgmXxadc:  45%|████▍     | 288/642 [00:00<00:00, 966.93 Segments/s]
# Aligning fvVhgmXxadc:  61%|██████    | 389/642 [00:00<00:00, 980.73 Segments/s]
# Aligning fvVhgmXxadc:  76%|███████▌  | 488/642 [00:00<00:00, 934.97 Segments/s]
# Aligning fvVhgmXxadc:  91%|█████████ | 582/642 [00:00<00:00, 920.81 Segments/s]
# Overall Progress:  78%|███████▊  | 72/92 [00:37<00:11,  1.80 Computational Sequence Entries/s]
#   0%|          | 0/306 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:   0%|          | 0/306 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:  42%|████▏     | 128/306 [00:00<00:00, 1270.47 Segments/s]
# Aligning iiK8YX8oH1E:  84%|████████▎ | 256/306 [00:00<00:00, 1218.91 Segments/s]
# Overall Progress:  79%|███████▉  | 73/92 [00:38<00:08,  2.14 Computational Sequence Entries/s]
#   0%|          | 0/638 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:   0%|          | 0/638 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:  16%|█▌        | 99/638 [00:00<00:00, 977.27 Segments/s]
# Aligning jUzDDGyPkXU:  31%|███       | 198/638 [00:00<00:00, 980.28 Segments/s]
# Aligning jUzDDGyPkXU:  47%|████▋     | 300/638 [00:00<00:00, 998.14 Segments/s]
# Aligning jUzDDGyPkXU:  64%|██████▍   | 407/638 [00:00<00:00, 1023.89 Segments/s]
# Aligning jUzDDGyPkXU:  80%|███████▉  | 510/638 [00:00<00:00, 1006.68 Segments/s]
# Aligning jUzDDGyPkXU:  96%|█████████▌| 611/638 [00:00<00:00, 990.95 Segments/s]
# Overall Progress:  80%|████████  | 74/92 [00:38<00:09,  1.92 Computational Sequence Entries/s]
#   0%|          | 0/623 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:   0%|          | 0/623 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:  15%|█▍        | 91/623 [00:00<00:00, 908.39 Segments/s]
# Aligning k5Y_838nuGo:  29%|██▉       | 182/623 [00:00<00:00, 874.29 Segments/s]
# Aligning k5Y_838nuGo:  44%|████▍     | 274/623 [00:00<00:00, 891.45 Segments/s]
# Aligning k5Y_838nuGo:  61%|██████    | 379/623 [00:00<00:00, 950.82 Segments/s]
# Aligning k5Y_838nuGo:  76%|███████▌  | 475/623 [00:00<00:00, 948.72 Segments/s]
# Aligning k5Y_838nuGo:  92%|█████████▏| 571/623 [00:00<00:00, 948.33 Segments/s]
# Overall Progress:  82%|████████▏ | 75/92 [00:39<00:09,  1.77 Computational Sequence Entries/s]
#   0%|          | 0/655 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|          | 0/655 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:  15%|█▍        | 97/655 [00:00<00:00, 963.93 Segments/s]
# Aligning lXPQBPVc5Cw:  30%|██▉       | 194/655 [00:00<00:00, 880.64 Segments/s]
# Aligning lXPQBPVc5Cw:  44%|████▍     | 290/655 [00:00<00:00, 912.21 Segments/s]
# Aligning lXPQBPVc5Cw:  59%|█████▉    | 386/655 [00:00<00:00, 928.52 Segments/s]
# Aligning lXPQBPVc5Cw:  73%|███████▎  | 481/655 [00:00<00:00, 935.14 Segments/s]
# Aligning lXPQBPVc5Cw:  88%|████████▊ | 579/655 [00:00<00:00, 949.10 Segments/s]
# Overall Progress:  83%|████████▎ | 76/92 [00:40<00:09,  1.64 Computational Sequence Entries/s]
#   0%|          | 0/593 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|          | 0/593 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:  16%|█▌        | 95/593 [00:00<00:00, 947.07 Segments/s]
# Aligning nbWiPyCm4g0:  33%|███▎      | 196/593 [00:00<00:00, 976.25 Segments/s]
# Aligning nbWiPyCm4g0:  50%|████▉     | 294/593 [00:00<00:00, 924.65 Segments/s]
# Aligning nbWiPyCm4g0:  68%|██████▊   | 401/593 [00:00<00:00, 976.26 Segments/s]
# Aligning nbWiPyCm4g0:  84%|████████▍ | 499/593 [00:00<00:00, 971.43 Segments/s]
# Overall Progress:  84%|████████▎ | 77/92 [00:40<00:09,  1.64 Computational Sequence Entries/s]
#   0%|          | 0/574 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|          | 0/574 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:  18%|█▊        | 101/574 [00:00<00:00, 1001.54 Segments/s]
# Aligning nzpVDcQ0ywM:  36%|███▌      | 207/574 [00:00<00:00, 1029.06 Segments/s]
# Aligning nzpVDcQ0ywM:  54%|█████▍    | 310/574 [00:00<00:00, 1019.53 Segments/s]
# Aligning nzpVDcQ0ywM:  72%|███████▏  | 412/574 [00:00<00:00, 984.94 Segments/s]
# Aligning nzpVDcQ0ywM:  90%|████████▉ | 514/574 [00:00<00:00, 993.22 Segments/s]
# Overall Progress:  85%|████████▍ | 78/92 [00:41<00:08,  1.66 Computational Sequence Entries/s]
#   0%|          | 0/413 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|          | 0/413 [00:00<?, ? Segments/s]
# ...
# Overall Progress:  22%|██▏       | 20/92 [00:00<00:01, 60.54 Computational Sequence Entries/s]
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning BXuRRbG0Ugk:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Bfr499ggo-0:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning BioHAh1qJAQ:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/26 [00:00<?, ? Segments/s]
# Aligning BvYR0L6f2Ig:   0%|          | 0/26 [00:00<?, ? Segments/s]
#
#   0%|          | 0/44 [00:00<?, ? Segments/s]
# Aligning Ci-AH39fi3Y:   0%|          | 0/44 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning Clx4VXItLTE:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning Dg_0XKD0Mf4:   0%|          | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  29%|██▉       | 27/92 [00:00<00:01, 59.90 Computational Sequence Entries/s]
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning G-xst2euQUc:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning G6GlGvlkxAQ:   0%|          | 0/29 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning GWuJjcEuzt8:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning HEsqda8_d0Q:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/39 [00:00<?, ? Segments/s]
# Aligning I5y0__X72p0:   0%|          | 0/39 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning Iu2PFX3z_1s:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning IumbAb8q2dM:   0%|          | 0/22 [00:00<?, ? Segments/s]
# Overall Progress:  37%|███▋      | 34/92 [00:00<00:00, 61.00 Computational Sequence Entries/s]
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning Jkswaaud0hk:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning LSi-o-IrDMs:   0%|          | 0/29 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning MLal-t_vJPM:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning Njd1F0vZSm4:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning Nzq88NnDkEk:   0%|          | 0/32 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning OQvJTdtJ2H4:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning OtBXNcAL_lE:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning Oz06ZWiO20M:   0%|          | 0/25 [00:00<?, ? Segments/s]
# Overall Progress:  46%|████▌     | 42/92 [00:00<00:00, 64.00 Computational Sequence Entries/s]
#   0%|          | 0/13 [00:00<?, ? Segments/s]
# Aligning POKffnXeBds:   0%|          | 0/13 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning PZ-lDQFboO8:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning QN9ZIUWUXsY:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning Qr1Ca94K55A:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning Sqr0AcuoNnk:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning TvyZBvOMOTc:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/17 [00:00<?, ? Segments/s]
# Aligning VCslbP0mgZI:   0%|          | 0/17 [00:00<?, ? Segments/s]
#
#   0%|          | 0/55 [00:00<?, ? Segments/s]
# Aligning VbQk4H8hgr0:   0%|          | 0/55 [00:00<?, ? Segments/s]
# Overall Progress:  54%|█████▍    | 50/92 [00:00<00:00, 63.27 Computational Sequence Entries/s]
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning Vj1wYRQjB-o:   0%|          | 0/9 [00:00<?, ? Segments/s]
#
#   0%|          | 0/32 [00:00<?, ? Segments/s]
# Aligning W8NXH0Djyww:   0%|          | 0/32 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning WKA5OygbEKI:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/11 [00:00<?, ? Segments/s]
# Aligning X3j2zQgwYgE:   0%|          | 0/11 [00:00<?, ? Segments/s]
#
#   0%|          | 0/9 [00:00<?, ? Segments/s]
# Aligning ZAIRrfG22O0:   0%|          | 0/9 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning ZUXBRvtny7o:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/28 [00:00<?, ? Segments/s]
# Aligning _dI--eQ6qVU:   0%|          | 0/28 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning aiEXnCPZubE:   0%|          | 0/30 [00:00<?, ? Segments/s]
# Overall Progress:  63%|██████▎   | 58/92 [00:00<00:00, 64.77 Computational Sequence Entries/s]
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning atnd_PF-Lbs:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/34 [00:00<?, ? Segments/s]
# Aligning bOL9jKpeJRs:   0%|          | 0/34 [00:00<?, ? Segments/s]
#
#   0%|          | 0/25 [00:00<?, ? Segments/s]
# Aligning bvLlb-M3UXU:   0%|          | 0/25 [00:00<?, ? Segments/s]
#
#   0%|          | 0/33 [00:00<?, ? Segments/s]
# Aligning c7UH_rxdZv4:   0%|          | 0/33 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning cM3Yna7AavY:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning cW1FSBF59ik:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/29 [00:00<?, ? Segments/s]
# Aligning cXypl4FnoZo:   0%|          | 0/29 [00:00<?, ? Segments/s]
# Overall Progress:  71%|███████   | 65/92 [00:01<00:00, 64.07 Computational Sequence Entries/s]
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning d3_k5Xpfmik:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/43 [00:00<?, ? Segments/s]
# Aligning d6hH302o4v8:   0%|          | 0/43 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning dq3Nf_lMPnE:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/19 [00:00<?, ? Segments/s]
# Aligning etzxEpPuc6I:   0%|          | 0/19 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning f9O3YtZ2VfI:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/15 [00:00<?, ? Segments/s]
# Aligning f_pcplsH_V0:   0%|          | 0/15 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning fvVhgmXxadc:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning iiK8YX8oH1E:   0%|          | 0/18 [00:00<?, ? Segments/s]
# Overall Progress:  79%|███████▉  | 73/92 [00:01<00:00, 66.80 Computational Sequence Entries/s]
#   0%|          | 0/27 [00:00<?, ? Segments/s]
# Aligning jUzDDGyPkXU:   0%|          | 0/27 [00:00<?, ? Segments/s]
#
#   0%|          | 0/31 [00:00<?, ? Segments/s]
# Aligning k5Y_838nuGo:   0%|          | 0/31 [00:00<?, ? Segments/s]
#
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning lXPQBPVc5Cw:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/10 [00:00<?, ? Segments/s]
# Aligning nbWiPyCm4g0:   0%|          | 0/10 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning nzpVDcQ0ywM:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/14 [00:00<?, ? Segments/s]
# Aligning ob23OKe5a9Q:   0%|          | 0/14 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning pLTX3ipuDJI:   0%|          | 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  87%|████████▋ | 80/92 [00:01<00:00, 66.55 Computational Sequence Entries/s]
#   0%|          | 0/21 [00:00<?, ? Segments/s]
# Aligning phBUpBr1hSo:   0%|          | 0/21 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning rnaNMUZpvvg:   0%|          | 0/22 [00:00<?, ? Segments/s]
#
#   0%|          | 0/18 [00:00<?, ? Segments/s]
# Aligning tIrG4oNLFzE:   0%|          | 0/18 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning tStelxIAHjw:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/20 [00:00<?, ? Segments/s]
# Aligning tmZoasNr4rU:   0%|          | 0/20 [00:00<?, ? Segments/s]
#
#   0%|          | 0/16 [00:00<?, ? Segments/s]
# Aligning v0zCBqDeKcE:   0%|          | 0/16 [00:00<?, ? Segments/s]
#
#   0%|          | 0/12 [00:00<?, ? Segments/s]
# Aligning vvZ4IcEtiZc:   0%|          | 0/12 [00:00<?, ? Segments/s]
#
#   0%|          | 0/22 [00:00<?, ? Segments/s]
# Aligning vyB00TXsimI:   0%|          | 0/22 [00:00<?, ? Segments/s]
# Overall Progress:  96%|█████████▌| 88/92 [00:01<00:00, 69.15 Computational Sequence Entries/s]
#   0%|          | 0/30 [00:00<?, ? Segments/s]
# Aligning wMbj6ajWbic:   0%|          | 0/30 [00:00<?, ? Segments/s]
#
#   0%|          | 0/24 [00:00<?, ? Segments/s]
# Aligning yDtzw_Y-7RU:   0%|          | 0/24 [00:00<?, ? Segments/s]
#
#   0%|          | 0/23 [00:00<?, ? Segments/s]
# Aligning yvsjCA6Y5Fc:   0%|          | 0/23 [00:00<?, ? Segments/s]
#
#   0%|          | 0/35 [00:00<?, ? Segments/s]
# Aligning zhpQhgha_KU:   0%|          | 0/35 [00:00<?, ? Segments/s]
# [2024-12-26 19:15:20.288] | Success | Alignment to <CMU_MOSI_Opinion_Labels> complete.
# [2024-12-26 19:15:20.288] | Status  | Replacing dataset content with aligned computational sequences
# [2024-12-26 19:15:20.330] | Success | Initialized empty <CMU_MOSI_TimestampedWords> computational sequence.
# [2024-12-26 19:15:20.330] | Status  | Checking the format of the data in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-26 19:15:20.334] | Success | <CMU_MOSI_TimestampedWords> computational sequence data in correct format.
# [2024-12-26 19:15:20.334] | Status  | Checking the format of the metadata in <CMU_MOSI_TimestampedWords> computational sequence ...
# [2024-12-26 19:15:20.334] | Warning | <CMU_MOSI_TimestampedWords> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:15:20.334] | Success | Initialized empty <CMU_MOSI_Visual_Facet_42> computational sequence.
# [2024-12-26 19:15:20.334] | Status  | Checking the format of the data in <CMU_MOSI_Visual_Facet_42> computational sequence ...
# [2024-12-26 19:15:20.338] | Success | <CMU_MOSI_Visual_Facet_42> computational sequence data in correct format.
# [2024-12-26 19:15:20.338] | Status  | Checking the format of the metadata in <CMU_MOSI_Visual_Facet_42> computational sequence ...
# [2024-12-26 19:15:20.338] | Warning | <CMU_MOSI_Visual_Facet_42> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:15:20.338] | Success | Initialized empty <CMU_MOSI_COVAREP> computational sequence.
# [2024-12-26 19:15:20.338] | Status  | Checking the format of the data in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-26 19:15:20.343] | Success | <CMU_MOSI_COVAREP> computational sequence data in correct format.
# [2024-12-26 19:15:20.344] | Status  | Checking the format of the metadata in <CMU_MOSI_COVAREP> computational sequence ...
# [2024-12-26 19:15:20.344] | Warning | <CMU_MOSI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-12-26 19:15:20.344] | Success | Initialized empty <CMU_MOSI_Opinion_Labels> computational sequence.
# [2024-12-26 19:15:20.344] | Status  | Checking the format of the data in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-26 19:15:20.347] | Success | <CMU_MOSI_Opinion_Labels> computational sequence data in correct format.
# [2024-12-26 19:15:20.347] | Status  | Checking the format of the metadata in <CMU_MOSI_Opinion_Labels> computational sequence ...
# [2024-12-26 19:15:20.347] | Warning | <CMU_MOSI_Opinion_Labels> computational sequence does not have all the required metadata ... continuing

# %%
print(dataset.keys())
# Out:
# dict_keys(['CMU_MOSI_TimestampedWords', 'CMU_MOSI_Visual_Facet_42', 'CMU_MOSI_COVAREP', 'CMU_MOSI_Opinion_Labels'])

# %%
import pickle
import numpy as np
from collections import defaultdict
from transformers import BertTokenizer, BertModel
import torch
from tqdm import tqdm
import torchtext as text
from torchtext.vocab import Vectors

# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
bert_model = BertModel.from_pretrained("bert-base-uncased")
bert_model.eval()  # Set BERT model to evaluation mode

# Dataset structure is assumed to be like dataset['modality']['video_id']['features']

DATASET = md.cmu_mosi
train_fold = DATASET.standard_folds.standard_train_fold
valid_fold = DATASET.standard_folds.standard_valid_fold
test_fold = DATASET.standard_folds.standard_test_fold

# Define folds
data_folds = {
    "train": train_fold,
    "valid": valid_fold,
    "test": test_fold,
}

# Define modalities and labels
AUDIO = 'CMU_MOSI_COVAREP'
VIDEO = 'CMU_MOSI_Visual_Facet_42'
WORD = 'CMU_MOSI_TimestampedWords'
LABEL = 'CMU_MOSI_Opinion_Labels'
MODALITIES = [AUDIO, VIDEO, WORD, LABEL]
SEQ_LEN = 50

# Padding helper function
def lpad(this_array, seq_len):
    temp_array = np.concatenate(
        [np.zeros([seq_len] + list(this_array.shape[1:])), this_array], axis=0
    )[-seq_len:, ...]
    return temp_array

# Detect entry fold
def detect_entry_fold(entry, folds):
    entry_id = entry.split("[")[0]
    for fold_name, fold_videos in folds.items():
        if entry_id in fold_videos:
            return fold_name
    return None

# Extract raw text data
def get_rawtext(dataset, text_field, video_ids):
    text_data = []
    valid_video_ids = []
    for vid in video_ids:
        try:
            words = [
                word[0].decode('utf-8')
                for word in dataset[text_field][vid]['features']
                if word[0] != b'sp'
            ]
            text_data.append(' '.join(words))
            valid_video_ids.append(vid)
        except KeyError:
            print(f"Missing text data for {vid}")
    return text_data, valid_video_ids

# Generate BERT embeddings
def bert_embeddings(text_data, max_seq_len=50):
    embeddings = []
    for text in tqdm(text_data, desc="Extracting BERT embeddings"):
        encoded = tokenizer(
            text,
            max_length=max_seq_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt",
        )
        with torch.no_grad():
            output = bert_model(**encoded)
            last_hidden_state = output.last_hidden_state.squeeze(0).numpy()
        embeddings.append(last_hidden_state)
    return np.array(embeddings)

# Generate GloVe embeddings
def get_word2id(text_data, vids):
    word2id = defaultdict(lambda: len(word2id))
    UNK = word2id['unk']
    data_processed = dict()
    for i, segment in enumerate(text_data):
        words = []
        _words = segment.split()
        for word in _words:
            words.append(word2id[word])
        words = np.asarray(words)
        data_processed[vids[i]] = words

    def _return_unk():
        return UNK

    word2id.default_factory = _return_unk
    return data_processed, word2id


def get_word_embeddings(word2id):
    glove_path = '../glove.840B.300d.txt'
    vec = Vectors(name=glove_path)
    tokens = []
    for w, _ in word2id.items():
        tokens.append(w)
    return vec.get_vecs_by_tokens(tokens, lower_case_backup=True)


def glove_embeddings(text_data, vids, paddings=50):
    data_prod, w2id = get_word2id(text_data, vids)
    word_embeddings_looks_up = get_word_embeddings(w2id)
    looks_up = word_embeddings_looks_up.numpy()
    embedd_data = []
    for vid in vids:
        d = data_prod[vid]
        tmp = []
        look_up = [looks_up[x] for x in d]
        if len(d) > paddings:
            for x in d[:paddings]:
                tmp.append(looks_up[x])
        else:
            for i in range(paddings - len(d)):
                tmp.append(np.zeros(300, ))
            for x in d:
                tmp.append(looks_up[x])
        embedd_data.append(np.array(tmp))
    return np.array(embedd_data)

# Process audio, visual, and text modalities
def process_modalities(dataset, video_ids, seq_len, text_embeddings):
    data = {fold: {mod: [] for mod in ["audio", "vision", "text", "labels"]} for fold in data_folds}
    data['train']['id'], data['valid']['id'], data['test']['id'] = [], [], []

    for i, vid in enumerate(video_ids):
        fold_name = detect_entry_fold(vid, data_folds)
        if not fold_name:
            print(f"Video {vid} doesn't belong to any fold")
            continue

        for modality, new_key in zip([AUDIO, VIDEO], ["audio", "vision"]):
            try:
                features = dataset[modality][vid]['features']
                data[fold_name][new_key].append(lpad(features, seq_len))
            except KeyError:
                print(f"Missing {modality} data for {vid}")

        try:
            label = dataset[LABEL][vid]['features']
            data[fold_name]["labels"].append(label)
        except KeyError:
            print(f"Missing label for {vid}")

        data[fold_name]["text"].append(text_embeddings[i])
        data[fold_name]['id'].append(vid)

    for fold_name in data_folds:
        for modality in ["audio", "vision", "text", "labels"]:
            data[fold_name][modality] = np.array(data[fold_name][modality])

    return data

# Main execution

# %%
video_ids = list(dataset[WORD].keys())
raw_text, valid_video_ids = get_rawtext(dataset, WORD, video_ids)
print(f"Extracted {len(raw_text)} valid text entries")

# Generate BERT embeddings
text_bert = bert_embeddings(raw_text, max_seq_len=SEQ_LEN)
print(f"BERT Embeddings Shape: {text_bert.shape}")

# Generate GloVe embeddings
text_glove = glove_embeddings(raw_text, valid_video_ids, paddings=SEQ_LEN)
print(f"GloVe Embeddings Shape: {text_glove.shape}")
# Out:
# Extracted 2183 valid text entries
# Extracting BERT embeddings: 100%|██████████| 2183/2183 [02:19<00:00, 15.59it/s]
# BERT Embeddings Shape: (2183, 50, 768)
# 100%|█████████▉| 2196016/2196017 [04:28<00:00, 8167.98it/s]
# GloVe Embeddings Shape: (2183, 50, 300)

# %%
# Process data using BERT embeddings
processed_data_bert = process_modalities(dataset, valid_video_ids, SEQ_LEN, text_bert)
# Save processed data
with open("mosi_raw_bert.pkl", "wb") as f:
    pickle.dump(processed_data_bert, f)
    
print("Processed data saved as mosi_raw_bert.pkl")
# Out:
# Processed data saved as mosi_raw_bert.pkl

# %%
# Process data using GloVe embeddings
processed_data_glove = process_modalities(dataset, valid_video_ids, SEQ_LEN, text_glove)

with open("mosi_raw_glove.pkl", "wb") as f:
    pickle.dump(processed_data_glove, f)
    
print("Processed data saved as mosi_raw_glove.pkl")
# Out:
# Processed data saved as mosi_raw_glove.pkl
